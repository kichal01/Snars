# %%
actors = {
    'Adrien Brody':2,
    'Cillian Murphy':2,
    'Brendan Fraser':1,
    'Will Smith':2,
    'Anthony Hopkins':2,
    'Joaquin Phoenix':2,
    'Rami Malek':2,
    'Gary Oldman':1,
    'Casey Affleck':1,
    'Leonardo DiCaprio':2,
    'Eddie Redmayne':2,
    'Matthew McConaughey':2,
    'Daniel Day-Lewis':2,
    'Jean Dujardin':2,
    'Colin Firth':1,
    'Jeff Bridges':1,
    'Sean Penn':1,
    'Daniel Day‑Lewis':2,
    'Forest Whitaker':1,
    'Philip Seymour Hoffman' :2,
    'Jamie Foxx':2,
    'Adrien Brody':2,
    'Denzel Washington':2,
    'Russell Crowe':2,
    'Roberto Benigni':2,
    'Geoffrey Rush': 2,
    'Jack Nicholson':1,
    'Nicolas Cage':2,
    'Tom Hanks':1,
    'Al Pacino':2,
    'Jeremy Irons':2,
    'Dustin Hoffman':1,
    'Michael Douglas':2,
    'Paul Newman':2,
    'William Hurt':2,
    'F. Murray Abraham':2,
    'Robert Duvall':2,
    'Ben Kingsley':2,
    'Henry Fonda':2,
    'Robert De Niro':1
}

# %%
import matplotlib.pyplot as plt
bacon_numbers = list(actors.values())
plt.hist(bacon_numbers, bins=5, edgecolor='black')
plt.xticks(sorted(set(bacon_numbers)))
plt.title("histogram of Bacon number among Oscar winners from 1980 to 2024")
plt.show()
